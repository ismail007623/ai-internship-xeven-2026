# %% [markdown]
# # Setup Project folder structure

# %% [markdown]
# In this task, I set up the Python development environment using uv and created the project structure for the AI internship. I organized the files by creating a day_01 folder, added an app.py file, and initialized a Git repository. The entire setup process was documented step by step in a Jupyter Notebook using Markdown explanations, and the project was pushed to a remote Git repository

# %% [markdown]
# # Project structure and 1st program

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Github Repo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Git command

# %% [markdown]
# ![image.png](attachment:image.png)
